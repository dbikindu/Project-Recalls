# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import tree

# %%
pet_finders = pd.read_csv('train.csv')
pet_finders.head()
# Out:
#    Type         Name  Age  Breed1  Breed2  Gender  Color1  Color2  Color3  \
# 0     2       Nibble    3     299       0       1       1       7       0
# 1     2  No Name Yet    1     265       0       1       1       2       0
# 2     1       Brisco    1     307       0       1       2       7       0
# 3     1         Miko    4     307       0       2       1       2       0
# 4     1       Hunter    1     307       0       1       1       0       0
#
#    MaturitySize  ...  Health  Quantity  Fee  State  \
# 0             1  ...       1         1  100  41326
# 1             2  ...       1         1    0  41401
# 2             2  ...       1         1    0  41326
# 3             2  ...       1         1  150  41401
# 4             2  ...       1         1    0  41326
#
#                           RescuerID  VideoAmt  \
# 0  8480853f516546f6cf33aa88cd76c379         0
# 1  3082c7125d8fb66f7dd4bff4192c8b14         0
# 2  fa90fa5b1ee11c86938398b60abc32cb         0
# ...

# %%
pet_finder= pet_finders.copy()

# %%
pet_finder.head()
# Out:
#    Type         Name  Age  Breed1  Breed2  Gender  Color1  Color2  Color3  \
# 0     2       Nibble    3     299       0       1       1       7       0
# 1     2  No Name Yet    1     265       0       1       1       2       0
# 2     1       Brisco    1     307       0       1       2       7       0
# 3     1         Miko    4     307       0       2       1       2       0
# 4     1       Hunter    1     307       0       1       1       0       0
#
#    MaturitySize  ...  Health  Quantity  Fee  State  \
# 0             1  ...       1         1  100  41326
# 1             2  ...       1         1    0  41401
# 2             2  ...       1         1    0  41326
# 3             2  ...       1         1  150  41401
# 4             2  ...       1         1    0  41326
#
#                           RescuerID  VideoAmt  \
# 0  8480853f516546f6cf33aa88cd76c379         0
# 1  3082c7125d8fb66f7dd4bff4192c8b14         0
# 2  fa90fa5b1ee11c86938398b60abc32cb         0
# ...

# %%
pet3_features = pet_finder[['PhotoAmt', 'Age', 'Color2','Color1','Breed1', 'AdoptionSpeed']]
pet3_features.head()
# Out:
#    PhotoAmt  Age  Color2  Color1  Breed1  AdoptionSpeed
# 0       1.0    3       7       1     299              2
# 1       2.0    1       2       1     265              0
# 2       7.0    1       7       2     307              3
# 3       8.0    4       2       1     307              2
# 4       3.0    1       0       1     307              2

# %%
# Assign the data to X and y

X = pet3_features[["PhotoAmt", "Age", "Color2", "Color1", "Breed1"]]
y = pet3_features["AdoptionSpeed"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (14993, 5) (14993, 1)

# %%
# Use train_test_split to create training and testing data

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

### END SOLUTION

# %%
# Create the model using LinearRegression

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
### END SOLUTION

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.0357122161505502
# Testing Score: 0.03709822043129629
